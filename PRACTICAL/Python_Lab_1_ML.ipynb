# %% [markdown]
# <a href="https://colab.research.google.com/github/chandrahasini2008/2520030086_ML_S4/blob/main/Python_Lab_1_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 5
y = 3.14
name = "CGPA"
is_placed = True
print(x, type(x))
print(y, type(y))
print(name, type(name))
print(is_placed, type(is_placed))
# Out:
# 5 <class 'int'>
# 3.14 <class 'float'>
# CGPA <class 'str'>
# True <class 'bool'>

# %%
# --- ARTHEMATIC OPERATORS ---
a = 7
b = 2
print("a + b =",a + b)
print("a - b =",a - b)
print("a * b =",a * b)
print("a / b =",a / b)
print("a ** 2 =",a ** 2)

# --- COMPARISION OPERATORS ---
cgpa = 8.4
print("cgpa == 8.4 :", cgpa == 8.4)
print("cgpa > 8    :", cgpa > 8)
print("cgpa < 6    :", cgpa < 6)

# --- LOGICAL OPERATIONS: and / or / not ---
attendance = 85
placed = (cgpa > 8) and (attendance > 80)
print("placed :",placed)
# Out:
# a + b = 9
# a - b = 5
# a * b = 14
# a / b = 3.5
# a ** 2 = 49
# cgpa == 8.4 : True
# cgpa > 8    : True
# cgpa < 6    : False
# placed : True

# %%
# --- STRINGS & F-STRINGS ---
model_name = "Logistic Regression"
accuracy = 0.87345
print("Accuracy of " + model_name + " is " + str(accuracy))
print(f"Accuracy of {model_name} is {accuracy}")
print(f"Accuracy of {model_name} is {accuracy:.3f}")
# Out:
# Accuracy of Logistic Regression is 0.87345
# Accuracy of Logistic Regression is 0.87345
# Accuracy of Logistic Regression is 0.873

# %%
features = ["CGPA", "AptitudeTestCore", "CodingTestCore", "MockinterviewScore"]
print(features)
print(features[0])
print(features[1])
print(features[-1])
print(len(features))
print(features[0:2])
features.append("Internships")
print(features)
# Out:
# ['CGPA', 'AptitudeTestCore', 'CodingTestCore', 'MockinterviewScore']
# CGPA
# AptitudeTestCore
# MockinterviewScore
# 4
# ['CGPA', 'AptitudeTestCore']
# ['CGPA', 'AptitudeTestCore', 'CodingTestCore', 'MockinterviewScore', 'Internships']

# %%
# --- LISTS & INDEXING ---
features = ["CGPA", "AptitudeTestCore", "CodingTestCore", "MockinterviewScore"]
print(features)
print(features[0])
print(features[1])
print(features[-1])
print(len(features))
print(features[0:2])
features.append("Internships")
print(features)

print(features[0:2])
features.append("Internships")
print(features)
# Out:
# ['CGPA', 'AptitudeTestCore', 'CodingTestCore', 'MockinterviewScore']
# CGPA
# AptitudeTestCore
# MockinterviewScore
# 4
# ['CGPA', 'AptitudeTestCore']
# ['CGPA', 'AptitudeTestCore', 'CodingTestCore', 'MockinterviewScore', 'Internships']
# ['CGPA', 'AptitudeTestCore']
# ['CGPA', 'AptitudeTestCore', 'CodingTestCore', 'MockinterviewScore', 'Internships', 'Internships']

# %%
from sklearn.linear_model import Ridge, Lasso, ElasticNet
models = {
    "Ridge":Ridge(alpha=1.0),
    "Lasso": Lasso(alpha=0.01),
    "ElasticNet": ElasticNet(alpha=0.01),
}
print(models)
print(models["Ridge"])
for name, model in models.items():
  print(f"Model name: {name} -> Object: {model}")
# Out:
# {'Ridge': Ridge(), 'Lasso': Lasso(alpha=0.01), 'ElasticNet': ElasticNet(alpha=0.01)}
# Ridge()
# Model name: Ridge -> Object: Ridge()
# Model name: Lasso -> Object: Lasso(alpha=0.01)
# Model name: ElasticNet -> Object: ElasticNet(alpha=0.01)

# %%
# --- IF / ELIF / ELSE ---
cgpa = 8.2
if cgpa >= 9:
  tier = "High"
elif cgpa >= 7:
  tier = "Mid"
else:
    tier = "Low"
print(f"CGPA {cgpa} falls int tier: {tier}")
missing_count = 0
if missing_count == 0:
  print("No missing values - safe to proceed.")
else:
  print("Missing values found - impute before modelling.")
# Out:
# CGPA 8.2 falls int tier: Mid
# No missing values - safe to proceed.
